# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# %%
load_dotenv()

user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')
db = os.getenv('DB_NAME')

engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}")

# %%
df = pd.read_sql_table('offers', engine)

# %% [markdown]
# # Job Title for Junior Spec

# %%
query = """
SELECT job_title, position_level FROM offers WHERE position_level = 'Młodszy specjalista (Junior)'
"""

df = pd.read_sql_query(query,engine)
df
# Out:
#                                            job_title  \
# 0            Junior System Integration Test Engineer
# 1     Software Engineer II - Infrastructure, EasyGCP
# 2                             Junior Data Consultant
# 3                Junior Data Scientist (Credit Risk)
# 4                            Python Junior Developer
# 5                Software Engineer II - Data Lineage
# 6   Software Engineer II - Chrome Browser Enterprise
# 7       Software Engineer - Early Career, 2025 Start
# 8            Junior System Integration Test Engineer
# 9     Software Engineer II - Infrastructure, EasyGCP
# 10                            Junior Data Consultant
# 11               Junior Data Scientist (Credit Risk)
# 12                           Python Junior Developer
# 13               Software Engineer II - Data Lineage
# 14  Software Engineer II - Chrome Browser Enterprise
# 15      Software Engineer - Early Career, 2025 Start
# 16           Junior System Integration Test Engineer
# 17    Software Engineer II - Infrastructure, EasyGCP
# 18                            Junior Data Consultant
# 19               Junior Data Scientist (Credit Risk)
# 20                           Python Junior Developer
# 21               Software Engineer II - Data Lineage
# 22  Software Engineer II - Chrome Browser Enterprise
# 23      Software Engineer - Early Career, 2025 Start
# 24           Junior System Integration Test Engineer
# 25    Software Engineer II - Infrastructure, EasyGCP
# 26                            Junior Data Consultant
# 27               Junior Data Scientist (Credit Risk)
# 28                           Python Junior Developer
# 29               Software Engineer II - Data Lineage
# 30  Software Engineer II - Chrome Browser Enterprise
# 31      Software Engineer - Early Career, 2025 Start
# 32           Junior System Integration Test Engineer
# 33    Software Engineer II - Infrastructure, EasyGCP
# 34                            Junior Data Consultant
# 35               Junior Data Scientist (Credit Risk)
# 36                           Python Junior Developer
# 37               Software Engineer II - Data Lineage
# 38  Software Engineer II - Chrome Browser Enterprise
# 39      Software Engineer - Early Career, 2025 Start
# 40           Junior System Integration Test Engineer
# 41    Software Engineer II - Infrastructure, EasyGCP
# 42                            Junior Data Consultant
# 43               Junior Data Scientist (Credit Risk)
# 44                           Python Junior Developer
# 45               Software Engineer II - Data Lineage
# 46  Software Engineer II - Chrome Browser Enterprise
# 47      Software Engineer - Early Career, 2025 Start
# 48           Junior System Integration Test Engineer
# 49    Software Engineer II - Infrastructure, EasyGCP
# 50                            Junior Data Consultant
# 51               Junior Data Scientist (Credit Risk)
# 52                           Python Junior Developer
# 53               Software Engineer II - Data Lineage
# 54  Software Engineer II - Chrome Browser Enterprise
# 11               Big Data Engineer  Warszawa
# 12                 Analityk Danych  Warszawa
# 13                Python Developer  Warszawa
# 14     Network Consulting Engineer  Warszawa
# 15  Analityk Biznesowy / obszar BI  Warszawa
# 16                Python Developer  Warszawa
# 17            Programista Big Data  Warszawa
# 18               Big Data Engineer  Warszawa
# 19     Network Consulting Engineer  Warszawa
# 20                 Analityk Danych  Warszawa
# 21  Analityk Biznesowy / obszar BI  Warszawa
# 22            Programista Big Data  Warszawa
# 23               Big Data Engineer  Warszawa
# 24                 Analityk Danych  Warszawa
# 25                Python Developer  Warszawa
# 26     Network Consulting Engineer  Warszawa
# 27                 Analityk Danych  Warszawa
# 28  Analityk Biznesowy / obszar BI  Warszawa
# 29            Programista Big Data  Warszawa
# 30               Big Data Engineer  Warszawa
# 31                Python Developer  Warszawa
# 32     Network Consulting Engineer  Warszawa
# 33  Analityk Biznesowy / obszar BI  Warszawa
# 34                Python Developer  Warszawa
# 35            Programista Big Data  Warszawa
# 36               Big Data Engineer  Warszawa
# 37     Network Consulting Engineer  Warszawa
# 38                 Analityk Danych  Warszawa
# 39  Analityk Biznesowy / obszar BI  Warszawa
# 40            Programista Big Data  Warszawa
# 41               Big Data Engineer  Warszawa

# %% [markdown]
# # The city with the most job offers

# %%
query = """
SELECT COUNT(*) AS number_of_jobs,
CASE
    WHEN city LIKE '%%Warszawa%%' THEN 'Warszawa'
    WHEN city LIKE '%%Kraków%%' THEN 'Kraków'
    WHEN city LIKE '%%Poznań%%' THEN 'Poznań'
    WHEN city LIKE '%%Wrocław%%' THEN 'Wrocław'
    WHEN city LIKE '%%Gdynia%%' THEN 'Gdynia'
    WHEN city LIKE '%%Gdańsk%%' THEN 'Gdańsk'
    WHEN city LIKE '%%Białystok%%' THEN 'Białystok'
    ELSE city
END AS city_sum
FROM offers
GROUP BY city_sum
ORDER BY number_of_jobs DESC
LIMIT 1
"""

df = pd.read_sql_query(query, engine)
df
# Out:
#    number_of_jobs simplified_city
# 0             182        Warszawa

# %% [markdown]
# # TOP 20 TECHNOLOGIES

# %%
df = pd.read_sql_table('offers', engine)
all_tech = df['technologies'].str.split(',').explode().str.strip()
count = all_tech.value_counts().head(20)
print(count)
# Out:
# technologies
# Python        350
# SQL           126
# JavaScript     70
# Java           70
# C++            63
# Bash           56
# C              56
# Docker         49
# Kubernetes     42
# Git            42
# Hadoop         28
# Grafana        28
# Ansible        28
# PyTorch        28
# PowerShell     28
# TensorFlow     21
# Jira           21
# R              21
# Linux          21
# Confluence     21
# Name: count, dtype: int64

# %% [markdown]
# # The highest model work

# %%
df = pd.read_sql_table('offers', engine)
model_work = df['model_work'].str.split(',').explode().str.strip()
count = model_work.value_counts()
print(count)
# Out:
# model_work
# Praca hybrydowa      259
# Praca zdalna         112
# Praca stacjonarna     56
# Name: count, dtype: int64
