# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# %%
load_dotenv()

user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')
db = os.getenv('DB_NAME')

engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}")

# %%
df = pd.read_sql_table('offers', engine)

# %% [markdown]
# # CLEANING

# %%
df.isnull().sum()
df_clean = df.drop_duplicates(subset=['job_title','company','city', 'position_level'])
df_clean.to_sql("offers_clean", engine, if_exists="replace", index=False)
# Out:
# 354

# %% [markdown]
# # Job Title for Junior Spec

# %%
query = """
SELECT job_title, position_level, city FROM offers WHERE position_level = 'Młodszy specjalista (Junior)'
"""

df = pd.read_sql_query(query,engine)
df
# Out:
#                                             job_title  \
# 0          Software Engineer - Early Career, Cloud AI
# 1             Software Engineer II - Ambient Platform
# 2                       Junior Data Engineer with SQL
# 3                    Junior IT Consultant & Developer
# 4         Junior Software Engineer (Python, Back-End)
# 5             Junior System Integration Test Engineer
# 6      Software Engineer II - Infrastructure, EasyGCP
# 7                              Junior Data Consultant
# 8                 Junior Data Scientist (Credit Risk)
# 9                             Python Junior Developer
# 10                Software Engineer II - Data Lineage
# 11   Software Engineer II - Chrome Browser Enterprise
# 12       Software Engineer - Early Career, 2025 Start
# 13                               Junior Java Engineer
# 14               Junior Developer (Technical Support)
# 15              IT Junior Developer w Laboratorium IT
# 16  Programista (Junior DevOps Engineer) w Dziale ...
# 17                             Junior Python Engineer
# 18                                Junior Data Analyst
# 19                               Junior Data Engineer
# 20                        Junior Engineer Opportunity
# 21                                 Junior AI Engineer
# 22                       Junior DevOps/Cloud Engineer
# 23                                 Młodszy informatyk
# 24                               Junior RPA Developer
# 25                                   Junior Developer
#
#                   position_level                        city
# 0   Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 1   Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 2   Młodszy specjalista (Junior)                    Warszawa
# 3   Młodszy specjalista (Junior)           Warszawa, Mokotów
# 4   Młodszy specjalista (Junior)           Gdynia, Mały Kack
# 5   Młodszy specjalista (Junior)           Gdynia, Mały Kack
# 6   Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 7   Młodszy specjalista (Junior)              Warszawa, Wola
# 8   Młodszy specjalista (Junior)              Warszawa, Wola
# 9   Młodszy specjalista (Junior)        Wrocław, Śródmieście
# 10  Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 11  Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 12  Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 13  Młodszy specjalista (Junior)        Kraków, Stare Miasto
# 14  Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 15  Młodszy specjalista (Junior)          Warszawa, Żoliborz
# 16  Młodszy specjalista (Junior)           Warszawa, Mokotów
# 17  Młodszy specjalista (Junior)              Warszawa, Wola
# 18  Młodszy specjalista (Junior)              Warszawa, Wola
# 19  Młodszy specjalista (Junior)    Warszawa, Praga-Południe
# 20  Młodszy specjalista (Junior)    Warszawa, Praga-Południe
# 21  Młodszy specjalista (Junior)                    Warszawa
# 22  Młodszy specjalista (Junior)       Warszawa, Śródmieście
# 23  Młodszy specjalista (Junior)  Kuranów (pow. żyrardowski)
# 24  Młodszy specjalista (Junior)                      Gdańsk
# 25  Młodszy specjalista (Junior)              Warszawa, Wola

# %% [markdown]
# # The city with the most job offers

# %%
query = """
SELECT COUNT(*) AS number_of_jobs,
CASE
    WHEN city LIKE '%%Warszawa%%' THEN 'Warszawa'
    WHEN city LIKE '%%Kraków%%' THEN 'Kraków'
    WHEN city LIKE '%%Poznań%%' THEN 'Poznań'
    WHEN city LIKE '%%Wrocław%%' THEN 'Wrocław'
    WHEN city LIKE '%%Gdynia%%' THEN 'Gdynia'
    WHEN city LIKE '%%Gdańsk%%' THEN 'Gdańsk'
    WHEN city LIKE '%%Białystok%%' THEN 'Białystok'
    ELSE city
END AS city_sum
FROM offers
GROUP BY city_sum
ORDER BY number_of_jobs DESC
LIMIT 1
"""

df = pd.read_sql_query(query, engine)
df
# Out:
#    number_of_jobs  city_sum
# 0             154  Warszawa

# %% [markdown]
# # TOP 20 TECHNOLOGIES except Python

# %%
query = """
SELECT 
    TRIM(tech) AS technology,
    COUNT(*) AS occurrences
FROM (
    SELECT unnest(string_to_array(technologies, ',')) AS tech
    FROM offers
    WHERE technologies IS NOT NULL
) AS techs
WHERE TRIM(tech) ILIKE '%%' AND TRIM(tech) NOT ILIKE 'python'
GROUP BY technology
ORDER BY occurrences DESC
LIMIT 20;
"""

df = pd.read_sql_query(query, engine)
df
# Out:
#                technology  occurrences
# 0                     SQL          138
# 1                     Git           54
# 2                  Docker           48
# 3                    Bash           43
# 4                    Java           42
# 5              JavaScript           42
# 6                     C++           42
# 7                     AWS           38
# 8              Kubernetes           38
# 9                   Linux           30
# 10              Terraform           29
# 11        Microsoft Azure           26
# 12                      C           24
# 13             PostgreSQL           23
# 14                Ansible           22
# 15                Jenkins           21
# 16                   Jira           19
# 17  Google Cloud Platform           18
# 18             PowerShell           18
# 19                Grafana           15
